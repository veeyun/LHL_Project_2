# %% [markdown]
# ### Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd
import numpy as np
import requests
import datetime
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import os
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# # Foursquare

# %%
df_fsq = pd.read_csv("../data/fsq_restaurant_bar_cafe_data.csv", index_col=0)
display(df_fsq.head(5))
# Out:
#                          Station_ID        Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 1  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 2  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 3  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 4  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
#
#                      FSQ_ID                    Venue Name   Latitude  \
# 0  4fd3a01be4b0540d9cb027ea                     Moii Cafe  49.262562
# 1  4b1db335f964a520211424e3                 Marulilu Cafe  49.263364
# 2  4aa8320cf964a520f94f20e3                  Blenz Coffee  49.263421
# 3  5bcb670ad0a149002dede4fa  Jammer Cafe and Urban Garage  49.263663
# 4  4be48099910020a134ced114         Cultured Coffee & Tea  49.260682
#
#     Longitude  Distance                                            Address  \
# 0 -123.115171        57  2559 Cambie St (btwn W Broadway & W 10th Ave),...
# 1 -123.113942        96  451W Broadway W (at Cambie St), Vancouver BC V...
# 2 -123.115731       144  521W Broadway W (at Cambie St), Vancouver BC V...
# 3 -123.112021       188                350 8th Ave W, Vancouver BC V5Y 3X2
# 4 -123.116309       223  555 12th Ave W (at Cambie St in City Square Sh...
#
#   Category name  Rating  Popularity  Price  Total Photos  Total Ratings  \
# 0          Café     8.0    0.221702    1.0          67.0           55.0
# 1          Café     8.2    0.953849    2.0         128.0          111.0
# 2          Café     5.4    0.977400    1.0          33.0           31.0
# 3          Café     NaN    0.550903    1.0           NaN            NaN
# 4   Coffee Shop     NaN    0.794641    1.0           NaN            NaN
#
#    Total Tips
# 0        18.0
# 1        32.0
# 2        15.0
# 3         NaN
# 4         NaN

# %%
df_fsq.shape
# Out:
# (6353, 15)

# %%
# count() will count everything excluding NaNs

df_fsq.count()
# Out:
# Station_ID       6353
# Station Name     6353
# FSQ_ID           6353
# Venue Name       6353
# Latitude         6353
# Longitude        6353
# Distance         6353
# Address          6353
# Category name    6353
# Rating           4993
# Popularity       6353
# Price            5887
# Total Photos     4952
# Total Ratings    4993
# Total Tips       4911
# dtype: int64

# %%
# Find duplicates
duplicate_rows_df_fsq = df_fsq[df_fsq.duplicated()]


print("number of duplicate rows: ", duplicate_rows_df_fsq.shape)

#shows that I have 348 duplicate rows
# Out:
# number of duplicate rows:  (348, 15)

# %%
# Drop duplicates in FSQ df

df_fsq = df_fsq.drop_duplicates()

df_fsq.head(5)
# Out:
#                          Station_ID        Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 1  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 2  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 3  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 4  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
#
#                      FSQ_ID                    Venue Name   Latitude  \
# 0  4fd3a01be4b0540d9cb027ea                     Moii Cafe  49.262562
# 1  4b1db335f964a520211424e3                 Marulilu Cafe  49.263364
# 2  4aa8320cf964a520f94f20e3                  Blenz Coffee  49.263421
# 3  5bcb670ad0a149002dede4fa  Jammer Cafe and Urban Garage  49.263663
# 4  4be48099910020a134ced114         Cultured Coffee & Tea  49.260682
#
#     Longitude  Distance                                            Address  \
# 0 -123.115171        57  2559 Cambie St (btwn W Broadway & W 10th Ave),...
# 1 -123.113942        96  451W Broadway W (at Cambie St), Vancouver BC V...
# 2 -123.115731       144  521W Broadway W (at Cambie St), Vancouver BC V...
# 3 -123.112021       188                350 8th Ave W, Vancouver BC V5Y 3X2
# 4 -123.116309       223  555 12th Ave W (at Cambie St in City Square Sh...
#
#   Category name  Rating  Popularity  Price  Total Photos  Total Ratings  \
# 0          Café     8.0    0.221702    1.0          67.0           55.0
# 1          Café     8.2    0.953849    2.0         128.0          111.0
# 2          Café     5.4    0.977400    1.0          33.0           31.0
# 3          Café     NaN    0.550903    1.0           NaN            NaN
# 4   Coffee Shop     NaN    0.794641    1.0           NaN            NaN
#
#    Total Tips
# 0        18.0
# 1        32.0
# 2        15.0
# 3         NaN
# 4         NaN

# %%
# FSQ - find shape after duplicates dropped

df_fsq.shape
# Out:
# (6005, 15)

# %%
# FSQ - Dropping the missing or null values.

print(df_fsq.isnull().sum())
# Out:
# Station_ID          0
# Station Name        0
# FSQ_ID              0
# Venue Name          0
# Latitude            0
# Longitude           0
# Distance            0
# Address             0
# Category name       0
# Rating           1283
# Popularity          0
# Price             461
# Total Photos     1324
# Total Ratings    1283
# Total Tips       1361
# dtype: int64

# %%
# FSQ - Dropping the missing values.

df_fsq = df_fsq.dropna()    
df_fsq.count()
# Out:
# Station_ID       4285
# Station Name     4285
# FSQ_ID           4285
# Venue Name       4285
# Latitude         4285
# Longitude        4285
# Distance         4285
# Address          4285
# Category name    4285
# Rating           4285
# Popularity       4285
# Price            4285
# Total Photos     4285
# Total Ratings    4285
# Total Tips       4285
# dtype: int64

# %%
# FSQ - Check if any NaN's left

print(df_fsq.isnull().sum())   # After dropping the values
# Out:
# Station_ID       0
# Station Name     0
# FSQ_ID           0
# Venue Name       0
# Latitude         0
# Longitude        0
# Distance         0
# Address          0
# Category name    0
# Rating           0
# Popularity       0
# Price            0
# Total Photos     0
# Total Ratings    0
# Total Tips       0
# dtype: int64

# %%
# FSQ - Detect Outliers

# %%
sns.boxplot(x=df_fsq['Distance'])
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
sns.boxplot(x=df_fsq['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
sns.boxplot(x=df_fsq['Popularity'])
# Out:
# <AxesSubplot:xlabel='Popularity'>

# %%
sns.boxplot(x=df_fsq['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(x=df_fsq['Total Photos'])
# Out:
# <AxesSubplot:xlabel='Total Photos'>

# %%
sns.boxplot(x=df_fsq['Total Ratings'])
# Out:
# <AxesSubplot:xlabel='Total Ratings'>

# %%
sns.boxplot(x=df_fsq['Total Tips'])
# Out:
# <AxesSubplot:xlabel='Total Tips'>

# %%
# FSQ - Drop Outliers using  IQR score technique

# %%
Q1 = df_fsq.quantile(0.25)
Q3 = df_fsq.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Latitude           0.017439
# Longitude          0.033427
# Distance         351.000000
# Rating             1.500000
# Popularity         0.065486
# Price              1.000000
# Total Photos      91.000000
# Total Ratings     72.000000
# Total Tips        21.000000
# dtype: float64

# %%
df_fsq = df_fsq[~((df_fsq < (Q1 - 1.5 * IQR)) |(df_fsq > (Q3 + 1.5 * IQR))).any(axis=1)]
df_fsq.shape

# Note: Not all outliers are likely removed
# Out:
# /var/folders/7g/kpw1gjw539l9x_wr2fw8njj80000gn/T/ipykernel_53398/2281037986.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_fsq = df_fsq[~((df_fsq < (Q1 - 1.5 * IQR)) |(df_fsq > (Q3 + 1.5 * IQR))).any(axis=1)]
# (3579, 15)

# %% [markdown]
# Original shape of FSQ df: (6353, 15)
#
# As seen above there were around 2774 rows were outliers.

# %% [markdown]
# ## Yelp

# %%
df_yelp = pd.read_csv("../data/yelp_restaurant_bar_cafe_data.csv", index_col=0)
display(df_yelp.head(5))
# Out:
#                          Station ID        Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 1  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 2  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 3  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 4  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
#
#                   Yelp ID                            Venue Name Price  \
# 0  PrKpa6Ejv1v1WvIIywYMvg                   Aperture Coffee Bar    $$
# 1  NensKn1MSVU_rm-1Y6WlFA                         Marulilu Cafe    $$
# 2  X-73k3cwBjjc170MOdPa7A                        Elysian Coffee    $$
# 3  dh-h2jbsa2ElN5Db0vfotQ  On the Grind - Pedalling Epic Coffee     $
# 4  UkSNdIF54dvas25eh_CmFw                      Caffe Cittadella    $$
#
#    Review Count  Rating   Latitude   Longitude    Distance  \
# 0           122     4.0  49.263204 -123.110470  295.924920
# 1           281     4.0  49.263380 -123.114150  102.329817
# 2           207     3.5  49.262940 -123.117280  221.080646
# 3             4     5.0  49.261226 -123.113927  144.308422
# 4           152     4.0  49.264809 -123.117267  331.734686
#
#                                           Address Category name
# 0   243 W Broadway, Vancouver, BC V5Y 3L1, Canada  Coffee & Tea
# 1   451 W Broadway, Vancouver, BC V5Y 1R4, Canada         Cafes
# 2   590 W Broadway, Vancouver, BC V5Z 1E9, Canada  Coffee & Tea
# 3                           Vancouver, BC, Canada  Coffee & Tea
# 4  2310 Ash Street, Vancouver, BC V5Z 3C2, Canada  Coffee & Tea

# %%
df_yelp.shape
# Out:
# (13615, 12)

# %%
# Yelp - Find duplicate values

duplicate_rows_df_yelp = df_yelp[df_yelp.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df_yelp.shape)
# Out:
# number of duplicate rows:  (1013, 12)

# %%
# Yelp - Count number of rows

df_yelp.count()
# Out:
# Station ID       13615
# Station Name     13615
# Yelp ID          13615
# Venue Name       13615
# Price            10045
# Review Count     13615
# Rating           13615
# Latitude         13615
# Longitude        13615
# Distance         13615
# Address          13615
# Category name    13615
# dtype: int64

# %% [markdown]
# ##### Above, there are 13615 rows and we are removing 1013 rows of duplicate data.

# %%
# Yelp - Remove duplicates

df_yelp = df_yelp.drop_duplicates()
df_yelp.head(5)
# Out:
#                          Station ID        Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 1  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 2  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 3  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
# 4  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie
#
#                   Yelp ID                            Venue Name Price  \
# 0  PrKpa6Ejv1v1WvIIywYMvg                   Aperture Coffee Bar    $$
# 1  NensKn1MSVU_rm-1Y6WlFA                         Marulilu Cafe    $$
# 2  X-73k3cwBjjc170MOdPa7A                        Elysian Coffee    $$
# 3  dh-h2jbsa2ElN5Db0vfotQ  On the Grind - Pedalling Epic Coffee     $
# 4  UkSNdIF54dvas25eh_CmFw                      Caffe Cittadella    $$
#
#    Review Count  Rating   Latitude   Longitude    Distance  \
# 0           122     4.0  49.263204 -123.110470  295.924920
# 1           281     4.0  49.263380 -123.114150  102.329817
# 2           207     3.5  49.262940 -123.117280  221.080646
# 3             4     5.0  49.261226 -123.113927  144.308422
# 4           152     4.0  49.264809 -123.117267  331.734686
#
#                                           Address Category name
# 0   243 W Broadway, Vancouver, BC V5Y 3L1, Canada  Coffee & Tea
# 1   451 W Broadway, Vancouver, BC V5Y 1R4, Canada         Cafes
# 2   590 W Broadway, Vancouver, BC V5Z 1E9, Canada  Coffee & Tea
# 3                           Vancouver, BC, Canada  Coffee & Tea
# 4  2310 Ash Street, Vancouver, BC V5Z 3C2, Canada  Coffee & Tea

# %%
df_yelp.count()
# Out:
# Station ID       12602
# Station Name     12602
# Yelp ID          12602
# Venue Name       12602
# Price             9287
# Review Count     12602
# Rating           12602
# Latitude         12602
# Longitude        12602
# Distance         12602
# Address          12602
# Category name    12602
# dtype: int64

# %%
# Yelp - Dropping the missing or null values

# %%
# Yelp - Find the sum of Nulls in df

print(df_yelp.isnull().sum())
# Out:
# Station ID          0
# Station Name        0
# Yelp ID             0
# Venue Name          0
# Price            3315
# Review Count        0
# Rating              0
# Latitude            0
# Longitude           0
# Distance            0
# Address             0
# Category name       0
# dtype: int64

# %%
# Yelp - # Dropping the missing values.

df_yelp = df_yelp.dropna()    
df_yelp.count()

# Now we have removed all the rows which contain the Null/NaN values (Price).
# Out:
# Station ID       9287
# Station Name     9287
# Yelp ID          9287
# Venue Name       9287
# Price            9287
# Review Count     9287
# Rating           9287
# Latitude         9287
# Longitude        9287
# Distance         9287
# Address          9287
# Category name    9287
# dtype: int64

# %%
# Yelp - Check if nulls/NaNs were removed after dropping the values

print(df_yelp.isnull().sum())
# Out:
# Station ID       0
# Station Name     0
# Yelp ID          0
# Venue Name       0
# Price            0
# Review Count     0
# Rating           0
# Latitude         0
# Longitude        0
# Distance         0
# Address          0
# Category name    0
# dtype: int64

# %%
# Yelp - Detecting Outliers

# %%
sns.boxplot(x=df_yelp['Review Count'])
# Out:
# <AxesSubplot:xlabel='Review Count'>

# %%
sns.boxplot(x=df_yelp['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
sns.boxplot(x=df_yelp['Distance'])
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
Q1 = df_yelp.quantile(0.25)
Q3 = df_yelp.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Review Count    188.000000
# Rating            0.500000
# Latitude          0.017174
# Longitude         0.033302
# Distance        438.488795
# dtype: float64

# %%
df_yelp = df_yelp[~((df_yelp < (Q1 - 1.5 * IQR)) |(df_yelp > (Q3 + 1.5 * IQR))).any(axis=1)]
df_yelp.shape
# Out:
# /var/folders/7g/kpw1gjw539l9x_wr2fw8njj80000gn/T/ipykernel_53398/1283869621.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_yelp = df_yelp[~((df_yelp < (Q1 - 1.5 * IQR)) |(df_yelp > (Q3 + 1.5 * IQR))).any(axis=1)]
# (8057, 12)

# %% [markdown]
# Yelp - original rows in df: 13615
#
# Above, there were around 5558 rows were outliers.

# %% [markdown]
# ## Vancouver Citybike Stations

# %%
df_vancouver_bikes = pd.read_csv("../data/vancouver_citybike_data.csv", index_col=0)
df_vancouver_bikes = df_vancouver_bikes.rename(columns={
    "id" : "Station_ID",
    "latitude" : "station_latitude",
    "longitude" : "station_longitude",
    "name" : "station_name"
    
})

df_vancouver_bikes = df_vancouver_bikes.drop(["timestamp", "extra.bank_card", "extra.uid"], axis=1)
display(df_vancouver_bikes.head(5))
# Out:
#    empty_slots  free_bikes                        Station_ID  \
# 0           19          16  7a19c49f486d7c0c02b3685d7b240448
# 1            1          15  32603a87cfca71d0f7dfa3513bad69d5
# 2            3          23  6d42fa40360f9a6b2bf641c7b8bb2862
# 3            8           8  66f873d641d448bd1572ab086665a458
# 4           11           5  485d4d24c803cfde829ab89699fed833
#
#    station_latitude  station_longitude                      station_name  \
# 0         49.262487        -123.114397                0001 10th & Cambie
# 1         49.274566        -123.121817  0004 Yaletown-Roundhouse Station
# 2         49.279764        -123.110154            0005 Dunsmuir & Beatty
# 3         49.260599        -123.113504     0007 12th & Yukon (City Hall)
# 4         49.264215        -123.117772                    0008 8th & Ash
#
#    extra.slots extra.status
# 0           35       online
# 1           16       online
# 2           26       online
# 3           16       online
# 4           16       online

# %%
df_vancouver_bikes.shape
# Out:
# (241, 8)

# %%
# check for duplicates 

duplicate_rows_df_vancouver_bikes = df_vancouver_bikes[df_vancouver_bikes.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df_vancouver_bikes.shape)

# result: there are no duplicate rows
# Out:
# number of duplicate rows:  (0, 8)

# %%
# Rename column name

df_vancouver_bikes = pd.read_csv("../data/vancouver_citybike_data.csv", index_col=0)
df_vancouver_bikes = df_vancouver_bikes.rename(columns={"id" : "Station_ID"})
display(df_vancouver_bikes.head(5))
# Out:
#    empty_slots  free_bikes                        Station_ID   latitude  \
# 0           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 1            1          15  32603a87cfca71d0f7dfa3513bad69d5  49.274566
# 2            3          23  6d42fa40360f9a6b2bf641c7b8bb2862  49.279764
# 3            8           8  66f873d641d448bd1572ab086665a458  49.260599
# 4           11           5  485d4d24c803cfde829ab89699fed833  49.264215
#
#     longitude                              name                    timestamp  \
# 0 -123.114397                0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 1 -123.121817  0004 Yaletown-Roundhouse Station  2022-11-05T16:52:07.468000Z
# 2 -123.110154            0005 Dunsmuir & Beatty  2022-11-05T16:52:07.468000Z
# 3 -123.113504     0007 12th & Yukon (City Hall)  2022-11-05T16:52:07.470000Z
# 4 -123.117772                    0008 8th & Ash  2022-11-05T16:52:07.471000Z
#
#    extra.bank_card  extra.slots extra.status  extra.uid
# 0            False           35       online          1
# 1            False           16       online          4
# 2            False           26       online          5
# 3            False           16       online          7
# 4            False           16       online          8

# %% [markdown]
# # Merge DataFrames

# %%
df_yelp = df_yelp.rename(columns={"Station ID" : "Station_ID"})

# df_fsq_yelp = pd.merge(df_fsq, df_yelp, right_on="Station_ID", left_on="Station_ID", how="left")
merge_on_list = ["Station_ID", "Station Name", "Venue Name"]

df_bikes_yelp = pd.merge(df_vancouver_bikes, df_yelp, on="Station_ID")
df_bikes_fsq = pd.merge(df_vancouver_bikes, df_fsq, on="Station_ID")

display(df_bikes_yelp.head(5))  # Yelp and Bike Stations
display(df_bikes_fsq.head(5))   # FSQ and Bike Stations
# Out:
#    empty_slots  free_bikes                        Station_ID   latitude  \
# 0           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 1           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 2           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 3           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 4           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
#
#     longitude                name                    timestamp  \
# 0 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 1 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 2 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 3 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 4 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
#
#    extra.bank_card  extra.slots extra.status  ...                 Yelp ID  \
# 0            False           35       online  ...  PrKpa6Ejv1v1WvIIywYMvg
# 1            False           35       online  ...  NensKn1MSVU_rm-1Y6WlFA
# 2            False           35       online  ...  X-73k3cwBjjc170MOdPa7A
# 3            False           35       online  ...  UkSNdIF54dvas25eh_CmFw
# 4            False           35       online  ...  NnaE4IKlc6XdYOUu4IOV5w
#
#              Venue Name Price Review Count Rating   Latitude   Longitude  \
# 0   Aperture Coffee Bar    $$          122    4.0  49.263204 -123.110470
# 1         Marulilu Cafe    $$          281    4.0  49.263380 -123.114150
# 2        Elysian Coffee    $$          207    3.5  49.262940 -123.117280
# 3      Caffe Cittadella    $$          152    4.0  49.264809 -123.117267
# 4  49th Parallel Coffee     $          495    4.0  49.259133 -123.100885
#
#       Distance                                          Address  Category name
# 0   295.924920    243 W Broadway, Vancouver, BC V5Y 3L1, Canada   Coffee & Tea
# 1   102.329817    451 W Broadway, Vancouver, BC V5Y 1R4, Canada          Cafes
# 2   221.080646    590 W Broadway, Vancouver, BC V5Z 1E9, Canada   Coffee & Tea
# 3   331.734686   2310 Ash Street, Vancouver, BC V5Z 3C2, Canada   Coffee & Tea
# 4  1049.076361  2902 Main Street, Vancouver, BC V5T 0C1, Canada          Cafes
#
# [5 rows x 22 columns]
#    empty_slots  free_bikes                        Station_ID   latitude  \
# 0           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 1           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 2           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 3           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 4           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
#
#     longitude                name                    timestamp  \
# 0 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 1 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 2 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 3 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 4 -123.114397  0001 10th & Cambie  2022-11-05T16:52:07.465000Z
#
#    extra.bank_card  extra.slots extra.status  ...   Longitude Distance  \
# 0            False           35       online  ... -123.113942       96
# 1            False           35       online  ... -123.115731      144
# 2            False           35       online  ... -123.110286      299
# 3            False           35       online  ... -123.117227      336
# 4            False           35       online  ... -123.119627      400
#
#                                              Address Category name  Rating  \
# 0  451W Broadway W (at Cambie St), Vancouver BC V...          Café     8.2
# 1  521W Broadway W (at Cambie St), Vancouver BC V...          Café     5.4
# 2  243 West Broadway (at Alberta St), Vancouver B...          Café     8.4
# 3   2310 Ash St (at W 7th Ave), Vancouver BC V5Z 3C2   Coffee Shop     8.6
# 4  695 Broadway W (at Heather St.), Vancouver BC ...          Café     5.6
#
#    Popularity  Price Total Photos Total Ratings  Total Tips
# 0    0.953849    2.0        128.0         111.0        32.0
# 1    0.977400    1.0         33.0          31.0        15.0
# 2    0.923845    1.0         68.0          96.0        30.0
# 3    0.961136    2.0        135.0          79.0        27.0
# 4    0.943686    1.0         29.0          24.0         6.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Provide a visualization that you used as part of your EDA process.
# Explain the initial pattern or relationship you discoved through this visualization.

# %% [markdown]
# # Yelp - Data Visualization

# %%
df_bikes_yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8057 entries, 0 to 8056
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   empty_slots      8057 non-null   int64
#  1   free_bikes       8057 non-null   int64
#  2   Station_ID       8057 non-null   object
#  3   latitude         8057 non-null   float64
#  4   longitude        8057 non-null   float64
#  5   name             8057 non-null   object
#  6   timestamp        8057 non-null   object
#  7   extra.bank_card  8057 non-null   bool
#  8   extra.slots      8057 non-null   int64
#  9   extra.status     8057 non-null   object
#  10  extra.uid        8057 non-null   int64
#  11  Station Name     8057 non-null   object
#  12  Yelp ID          8057 non-null   object
#  13  Venue Name       8057 non-null   object
#  14  Price            8057 non-null   object
#  15  Review Count     8057 non-null   int64
#  16  Rating           8057 non-null   float64
#  17  Latitude         8057 non-null   float64
#  18  Longitude        8057 non-null   float64
#  19  Distance         8057 non-null   float64
#  20  Address          8057 non-null   object
#  21  Category name    8057 non-null   object
# dtypes: bool(1), float64(6), int64(5), object(10)
# memory usage: 1.4+ MB

# %%
df_bikes_yelp.describe()
# Out:
#        empty_slots   free_bikes     latitude    longitude  extra.slots  \
# count  8057.000000  8057.000000  8057.000000  8057.000000  8057.000000
# mean      9.970585     8.661909    49.271995  -123.114742    18.660916
# std       5.802548     5.682001     0.010805     0.026979     5.215058
# min       0.000000     0.000000    49.238105  -123.191458    12.000000
# 25%       5.000000     4.000000    49.263523  -123.132778    14.000000
# 50%      10.000000     8.000000    49.271721  -123.115392    18.000000
# 75%      14.000000    13.000000    49.280332  -123.097052    20.000000
# max      37.000000    23.000000    49.302577  -123.056909    40.000000
#
#          extra.uid  Review Count       Rating     Latitude    Longitude  \
# count  8057.000000   8057.000000  8057.000000  8057.000000  8057.000000
# mean    185.798933    137.710935     3.936949    49.272315  -123.114416
# std     137.279714    123.135509     0.422121     0.010514     0.026522
# min       1.000000      1.000000     3.000000    49.240341  -123.183875
# 25%      78.000000     46.000000     3.500000    49.264063  -123.133070
# 50%     172.000000     96.000000     4.000000    49.271895  -123.115380
# 75%     246.000000    195.000000     4.000000    49.281060  -123.100446
# max     642.000000    518.000000     4.500000    49.301253  -123.051462
#
#           Distance
# count  8057.000000
# mean    569.891836
# std     287.788739
# min       1.973312
# 25%     343.387178
# 50%     554.398936
# 75%     781.434814
# max    1386.683256

# %%
df_bikes_yelp.corr()
# Out:
#                  empty_slots  free_bikes  latitude  longitude  \
# empty_slots         1.000000   -0.586408 -0.103791  -0.084854
# free_bikes         -0.586408    1.000000  0.269920  -0.102234
# latitude           -0.103791    0.269920  1.000000  -0.075567
# longitude          -0.084854   -0.102234 -0.075567   1.000000
# extra.bank_card          NaN         NaN       NaN        NaN
# extra.slots         0.475063    0.433573  0.176417  -0.204871
# extra.uid           0.012763   -0.187718 -0.342449   0.203328
# Review Count       -0.005064    0.034335  0.072878  -0.040827
# Rating             -0.015682    0.046514  0.130575   0.040720
# Latitude           -0.108954    0.249482  0.926608  -0.070105
# Longitude          -0.085124   -0.084808 -0.076548   0.973763
# Distance           -0.009319   -0.005077 -0.093044  -0.032572
#
#                  extra.bank_card  extra.slots  extra.uid  Review Count  \
# empty_slots                  NaN     0.475063   0.012763     -0.005064
# free_bikes                   NaN     0.433573  -0.187718      0.034335
# latitude                     NaN     0.176417  -0.342449      0.072878
# longitude                    NaN    -0.204871   0.203328     -0.040827
# extra.bank_card              NaN          NaN        NaN           NaN
# extra.slots                  NaN     1.000000  -0.189999      0.031594
# extra.uid                    NaN    -0.189999   1.000000     -0.099146
# Review Count                 NaN     0.031594  -0.099146      1.000000
# Rating                       NaN     0.032860  -0.058705      0.066472
# Latitude                     NaN     0.148172  -0.373291      0.075682
# Longitude                    NaN    -0.186085   0.195689     -0.040592
# Distance                     NaN    -0.016600   0.096187     -0.024626
#
#                    Rating  Latitude  Longitude  Distance
# empty_slots     -0.015682 -0.108954  -0.085124 -0.009319
# free_bikes       0.046514  0.249482  -0.084808 -0.005077
# latitude         0.130575  0.926608  -0.076548 -0.093044
# longitude        0.040720 -0.070105   0.973763 -0.032572
# extra.bank_card       NaN       NaN        NaN       NaN
# extra.slots      0.032860  0.148172  -0.186085 -0.016600
# extra.uid       -0.058705 -0.373291   0.195689  0.096187
# Review Count     0.066472  0.075682  -0.040592 -0.024626
# Rating           1.000000  0.143566   0.042550  0.050208
# Latitude         0.143566  1.000000  -0.071907 -0.067396
# Longitude        0.042550 -0.071907   1.000000 -0.019784
# Distance         0.050208 -0.067396  -0.019784  1.000000

# %%
sns.heatmap(df_bikes_yelp.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df_bikes_yelp)
plt.show()

# %%
df_bikes_fsq.corr()

# %%
sns.heatmap(df_bikes_fsq.corr())
# Out:
# <AxesSubplot:>

# %%
# Foursquare

sns.scatterplot(data=df_bikes_fsq, x="extra.slots", y="Total Ratings")
plt.show()

sns.jointplot(data=df_bikes_fsq, x="free_bikes", y="Total Photos")
plt.show()

sns.jointplot(data=df_bikes_fsq, x="extra.slots", y="Total Photos")
plt.show()

sns.jointplot(data=df_bikes_fsq, x="Rating", y="Total Photos")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [333], in <cell line: 4>()
#       1 # Foursquare
#       3 sns.scatterplot(data=df_bikes_fsq, x="extra.slots", y="Total Ratings")
# ----> 4 plt.show()
#       6 sns.jointplot(data=df_bikes_fsq, x="free_bikes", y="Total Photos")
#       7 plt.show()
#
# AttributeError: 'PairGrid' object has no attribute 'show'

# %% [markdown]
# As seen above, number of bikes does not seem to correlate with the number of photos taken at the POI location.

# %%
plt = sns.pairplot(df_bikes_fsq)
plt.show()

# %%
df_bikes_fsq.to_csv("../data/bikes_fsq_data.csv")

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
        cursor.close()
        connection.close()
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
connection = create_connection("project_2.sqlite")
# Out:
# Connection to SQLite DB successful

# %%
create_bike_data_table = """
CREATE TABLE IF NOT EXISTS bike_stations (
    Station_ID VARCHAR NOT NULL,
    name TEXT NOT NULL,
    total_slots INTEGER,
    empty_slots INTEGER,
    free_bikes INTEGER,
    longitude FLOAT,
    latitude FLOAT,
    status TEXT
);
"""

# %%
execute_query(connection, create_bike_data_table)

# %%
# Rename columns

df_bikes = df_vancouver_bikes.rename(columns={
    'station_latitude' : 'latitude',
    'station_longitude': 'longitude',
    'station_name' : 'name',
    'extra.slots' : 'total_slots',
    'extra.status' : 'status'
})
display(df_bikes.head(5))
# Out:
#    empty_slots  free_bikes                        Station_ID   latitude  \
# 0           19          16  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 1            1          15  32603a87cfca71d0f7dfa3513bad69d5  49.274566
# 2            3          23  6d42fa40360f9a6b2bf641c7b8bb2862  49.279764
# 3            8           8  66f873d641d448bd1572ab086665a458  49.260599
# 4           11           5  485d4d24c803cfde829ab89699fed833  49.264215
#
#     longitude                              name                    timestamp  \
# 0 -123.114397                0001 10th & Cambie  2022-11-05T16:52:07.465000Z
# 1 -123.121817  0004 Yaletown-Roundhouse Station  2022-11-05T16:52:07.468000Z
# 2 -123.110154            0005 Dunsmuir & Beatty  2022-11-05T16:52:07.468000Z
# 3 -123.113504     0007 12th & Yukon (City Hall)  2022-11-05T16:52:07.470000Z
# 4 -123.117772                    0008 8th & Ash  2022-11-05T16:52:07.471000Z
#
#    extra.bank_card  total_slots  status  extra.uid
# 0            False           35  online          1
# 1            False           16  online          4
# 2            False           26  online          5
# 3            False           16  online          7
# 4            False           16  online          8

# %%
# df_bikes.to_sql(name="bike_stations", con=connection, if_exists='append', index=False)

# %%
# select_bike_stations = "SELECT * from bike_stations"
# bike_stations = execute_query(connection, select_bike_stations)

# for station in bike_stations:
#     print(station)

# %%
df_bikes.to_sql('bike_stations', con=connection, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/io/sql.py:2023, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2022 try:
# -> 2023     cur.execute(*args, **kwargs)
#    2024     return cur
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [319], in <cell line: 1>()
# ----> 1 df_bikes.to_sql('bike_stations', con=connection, if_exists='replace', index=False)
#
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/io/sql.py:2192, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2181             raise ValueError(f"{col} ({my_type}) not a string")
#    2183 table = SQLiteTable(
#    2184     name,
#    2185     self,
#    (...)
#    2190     dtype=dtype,
#    2191 )
# -> 2192 table.create()
#    2193 return table.insert(chunksize, method)
#
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/io/sql.py:836, in SQLTable.create(self)
#     834     raise ValueError(f"Table '{self.name}' already exists.")
#     835 elif self.if_exists == "replace":
# --> 836     self.pd_sql.drop_table(self.name, self.schema)
#     837     self._execute_create()
#     838 elif self.if_exists == "append":
#
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/io/sql.py:2207, in SQLiteDatabase.drop_table(self, name, schema)
#    2205 def drop_table(self, name: str, schema: str | None = None):
#    2206     drop_sql = f"DROP TABLE {_get_valid_sqlite_name(name)}"
# -> 2207     self.execute(drop_sql)
#
# File ~/opt/anaconda3/envs/LHL_env/lib/python3.9/site-packages/pandas/io/sql.py:2035, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2032     raise ex from inner_exc
#    2034 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2035 raise ex from exc
#
# DatabaseError: Execution failed on sql 'DROP TABLE "bike_stations"': database is locked

# %%
connection.execute("SELECT * from bike_stations").fetchall()
# Out:
# [(0,
#   19,
#   16,
#   '7a19c49f486d7c0c02b3685d7b240448',
#   49.262487,
#   -123.114397,
#   '0001 10th & Cambie',
#   35,
#   'online'),
#  (1,
#   1,
#   15,
#   '32603a87cfca71d0f7dfa3513bad69d5',
#   49.274566,
#   -123.121817,
#   '0004 Yaletown-Roundhouse Station',
#   16,
#   'online'),
#  (2,
#   3,
#   23,
#   '6d42fa40360f9a6b2bf641c7b8bb2862',
#   49.279764,
#   -123.110154,
#   '0005 Dunsmuir & Beatty',
#   26,
#   'online'),
#  (3,
#   8,
#   8,
#   '66f873d641d448bd1572ab086665a458',
#   49.260599,
#   -123.113504,
#   '0007 12th & Yukon (City Hall)',
#   16,
#   'online'),
#  (4,
#   11,
#   5,
#   '485d4d24c803cfde829ab89699fed833',
#   49.264215,
#   -123.117772,
#   '0008 8th & Ash',
#   16,
#   'online'),
#  (5,
#   11,
#   3,
#   'b07d513f87897cff7319a0e59d7e567c',
#   49.270877,
#   -123.115103,
#   '0009 Spyglass & Seawall',
#   14,
#   'online'),
#  (6,
#   2,
#   12,
#   'd1c9556d92f329703229fb3e33899a3b',
#   49.26893,
#   -123.11813,
#   '0010 Stamps Landing',
#   14,
#   'online'),
#  (7,
#   7,
#   13,
#   '95e624191c655f50e401d280cd39a9ad',
#   49.271721,
#   -123.104207,
#   '0011 Ontario & Seawall',
#   20,
#   'online'),
#  (8,
#   10,
#   16,
#   '3e112f9fe877e0003780386359060ae6',
#   49.287214,
#   -123.11287,
#   '0014 Canada Place',
#   26,
#   'online'),
#  (9,
#   13,
#   7,
#   '6993b3dbb0758927967592ea612a2b1e',
#   49.282409,
#   -123.118541,
#   '0015 Granville & Georgia',
#   20,
#   'online'),
#  (10,
#   8,
#   18,
#   'bf8408067b0e0c963f3ff526977bcef3',
#   49.287097,
#   -123.118551,
#   '0016 Pender & Burrard',
#   26,
#   'online'),
#  (11,
#   14,
#   8,
#   'd2244f1a81d317c76cabd65e81250835',
#   49.273471,
#   -123.118016,
#   '0017 Marinaside & Davie',
#   22,
#   'online'),
#  (12,
#   14,
#   16,
#   '0b543fc4e694fe07a54dac48bb1b3390',
#   49.282758,
#   -123.122092,
#   '0019 Robson & Hornby',
#   30,
#   'online'),
#  (13,
#   1,
#   21,
#   '1b4c6f63f4bfbbd983992dbdca776865',
#   49.286042,
#   -123.113176,
#   '0021 Cordova & Granville',
#   22,
#   'online'),
#  (14,
#   4,
#   18,
#   'fbb1d30d7f30b049873f5be5688563d4',
#   49.28602,
#   -123.116624,
#   '0024 Hornby & Pender',
#   22,
#   'online'),
#  (15,
#   19,
#   1,
#   '7181df50ee1d1a05559399211382b7c8',
#   49.279739,
#   -123.116251,
#   '0025 Homer & Robson (Vancouver Public Library)',
#   20,
#   'online'),
#  (16,
#   16,
#   4,
#   '2ef000bc9d4650d8cc6198c4d570b19f',
#   49.277483,
#   -123.114279,
#   '0026 Beatty & Robson',
#   20,
#   'online'),
#  (17,
#   10,
#   4,
#   'b7683a86874e6300fd89f4cc0b075f57',
#   49.275679,
#   -123.116963,
#   '0027 Beatty & Nelson',
#   14,
#   'online'),
#  (18,
#   3,
#   19,
#   '3367c1e1dbf73caf7c10e4c96a92f58d',
#   49.282759,
#   -123.106955,
#   '0030 Abbott & Cordova',
#   22,
#   'online'),
#  (19,
#   11,
#   7,
#   '1d7e73b3321ebb6713774d376247d9f9',
#   49.288444,
#   -123.139203,
#   '0032 Comox & Denman',
#   18,
#   'online'),
#  (20,
#   1,
#   13,
#   '664502c28e8147615f17b8ea355f40d0',
#   49.289124,
#   -123.12196,
#   '0034 Cordova & Bute',
#   14,
#   'online'),
#  (21,
#   15,
#   3,
#   '6c24a62b5ee0a2a8014eb0dfb6d40025',
#   49.28062,
#   -123.12482,
#   '0037 Hornby & Nelson',
#   18,
#   'online'),
#  (22,
#   11,
#   4,
#   'fad9ebcf614dd1a72593a34072ff76f8',
#   49.279938,
#   -123.127478,
#   '0039 Helmcken & Burrard',
#   15,
#   'online'),
#  (23,
#   5,
#   9,
#   '3a4131fa94946d93d3529136efd62413',
#   49.273663,
#   -123.127075,
#   '0044 Pacific & Richards',
#   14,
#   'online'),
#  (24,
#   1,
#   13,
#   '25318ec3e06fae1397a3a2f645104149',
#   49.28972,
#   -123.144028,
#   '0047 Chilco & Beach',
#   14,
#   'online'),
#  (25,
#   10,
#   2,
#   '444991edc9550be0908f032da5e3c95f',
#   49.285253,
#   -123.134356,
#   '0048 Comox & Broughton',
#   12,
#   'online'),
#  (26,
#   15,
#   7,
#   '434b6f4e7fc30198f901b60fc905f609',
#   49.283343,
#   -123.131099,
#   '0050 Bute & Comox',
#   22,
#   'online'),
#  (27,
#   18,
#   14,
#   'f97d5bf41f35aa181288429fb52e3488',
#   49.284605,
#   -123.108662,
#   '0052 Cambie & Water',
#   32,
#   'online'),
#  (28,
#   12,
#   16,
#   'fef69fb400210d861107a61db954d037',
#   49.279821,
#   -123.10802,
#   '0053 Keefer & Abbott',
#   28,
#   'online'),
#  (29,
#   1,
#   15,
#   '9d3123425823420514b8ad410074f02d',
#   49.278004,
#   -123.105664,
#   '0054 Expo & Carrall',
#   16,
#   'online'),
#  (30,
#   4,
#   10,
#   'f1ca711137cde59e824167a4274df888',
#   49.279342,
#   -123.101822,
#   '0055 Keefer & Columbia',
#   14,
#   'online'),
#  (31,
#   9,
#   17,
#   '4f6ebf2026d540ffe40e29a80138ad5e',
#   49.273833,
#   -123.114373,
#   '0057 Marinaside & Cooperage',
#   26,
#   'online'),
#  (32,
#   4,
#   22,
#   'be14efdc86dedd6a8cd338e78ab4e7c7',
#   49.28526,
#   -123.141809,
#   '0060 Bidwell & Burnaby',
#   26,
#   'online'),
#  (33,
#   24,
#   6,
#   '6ddeafa873279951630a00191333c45d',
#   49.281506,
#   -123.120101,
#   '0063 Robson & Granville',
#   30,
#   'online'),
#  (34,
#   5,
#   9,
#   'c7b5bec0b2f4ab9a2d3f9d837725620c',
#   49.276115,
#   -123.114496,
#   '0064 Expo & Smithe',
#   14,
#   'online'),
#  (35,
#   5,
#   17,
#   'b9fd847d53fe45658fee4c46e7f562b8',
#   49.272827,
#   -123.147744,
#   '0065 Cypress & Cornwall',
#   22,
#   'online'),
#  (36,
#   10,
#   18,
#   'c2be5403b1c101e8032cf6696457200e',
#   49.269361,
#   -123.13782,
#   '0066 Anderson & 2nd',
#   28,
#   'online'),
#  (37,
#   7,
#   7,
#   '71c064fa93cab5f0b7306e6c923b77c4',
#   49.2653,
#   -123.13811,
#   '0069 7th & Granville',
#   14,
#   'online'),
#  (38,
#   10,
#   4,
#   '96bf713e60bc35cc2feb5fd53a4f3471',
#   49.262598,
#   -123.138921,
#   '0070 10th & Granville',
#   14,
#   'online'),
#  (39,
#   7,
#   7,
#   '8dc684732a2a25bdf63ec0ecccee4e6e',
#   49.25894,
#   -123.139272,
#   '0071 14th & Granville',
#   14,
#   'online'),
#  (40,
#   11,
#   3,
#   '686c0fdb962e26e274d81fc286c010dd',
#   49.258763,
#   -123.115392,
#   '0072 14th & Cambie',
#   14,
#   'online'),
#  (41,
#   16,
#   4,
#   '0cf6cd1809fa7f510812f5b052f578c4',
#   49.266724,
#   -123.104824,
#   '0073 Ontario & 5th',
#   20,
#   'online'),
#  (42,
#   11,
#   7,
#   '93c88a18c673e2c72a6afa93d6b89f18',
#   49.262141,
#   -123.101961,
#   '0074 10th & Main',
#   18,
#   'online'),
#  (43,
#   4,
#   14,
#   '8fb5ce1e34ad31de940481953aea452c',
#   49.268269,
#   -123.147885,
#   '0076 Cypress & 4th',
#   18,
#   'online'),
#  (44,
#   14,
#   14,
#   'aa704bfba40286bd0661b64d1f75e778',
#   49.275717,
#   -123.142564,
#   '0077 Vanier Park',
#   28,
#   'online'),
#  (45,
#   12,
#   8,
#   '8c9ea7f2132376859ef34fab981d6932',
#   49.276436,
#   -123.11877,
#   '0078 Nelson & Mainland',
#   20,
#   'online'),
#  (46,
#   16,
#   2,
#   '1d4153659a0a0a2089078c739df6737d',
#   49.277844,
#   -123.120942,
#   '0079 Nelson & Richards',
#   18,
#   'online'),
#  (47,
#   6,
#   12,
#   'fbb4c06b719596c21f91fd51ef6d4710',
#   49.265089,
#   -123.119425,
#   '0081 7th & Heather',
#   18,
#   'online'),
#  (48,
#   18,
#   2,
#   '72c1049dfbbde7c24ec45c14f1a5ee85',
#   49.28026,
#   -123.135244,
#   '0088 Harwood & Bute',
#   20,
#   'online'),
#  (49,
#   10,
#   8,
#   '00fa94ad698dc4a9e4d708d6fd32f294',
#   49.291909,
#   -123.140713,
#   '0092 Chilco & Barclay',
#   18,
#   'online'),
#  (50,
#   6,
#   10,
#   'efa947b901a2cf85b58320b3ad26a2fe',
#   49.293257,
#   -123.138563,
#   '0093 Chilco & Robson',
#   16,
#   'online'),
#  (51,
#   7,
#   11,
#   '66a53e9c32e4f5c724f9478240020142',
#   49.288011,
#   -123.132006,
#   '0096 Nicola & Robson',
#   18,
#   'online'),
#  (52,
#   8,
#   10,
#   '97b25faf822b93fdbf72da1d594c0288',
#   49.28117,
#   -123.104419,
#   '0098 Carrall & Hastings',
#   18,
#   'online'),
#  (53,
#   23,
#   5,
#   '6c7fb9043e6df5a4cc50404581a947b9',
#   49.283227,
#   -123.120523,
#   '0099 Vancouver Art Gallery - North Plaza',
#   28,
#   'online'),
#  (54,
#   6,
#   10,
#   '30bf49544b1c864688b78172d42cca5e',
#   49.299292,
#   -123.130281,
#   '0101 Stanley Park - Vancouver Aquarium',
#   16,
#   'online'),
#  (55,
#   0,
#   16,
#   '9f63cebac9073eac3e90be2b9a91b02b',
#   49.29534,
#   -123.150433,
#   '0102 Stanley Park - Second Beach North',
#   16,
#   'online'),
#  (56,
#   10,
#   8,
#   '9aa325529164ec68b4d96c4f1c4fc7c1',
#   49.294318,
#   -123.148808,
#   '0104 Stanley Park - Second Beach South',
#   18,
#   'online'),
#  (57,
#   11,
#   9,
#   'e3d32ad772a5898c3b96c4d23d2cd542',
#   49.298657,
#   -123.121176,
#   '0105 Stanley Park - Totem Poles',
#   20,
#   'online'),
#  (58,
#   7,
#   11,
#   '625a2ad202275c8e2be3ce868e85b105',
#   49.259183,
#   -123.120126,
#   '0106 Heather & 14th',
#   18,
#   'online'),
#  (59,
#   14,
#   2,
#   '6c0de983fb47a3439a9e3c36a3d15804',
#   49.263837,
#   -123.105173,
#   '0107 8th & Ontario',
#   16,
#   'online'),
#  (60,
#   16,
#   10,
#   '92c9e62c0b42adf4759c430009d3987a',
#   49.270721,
#   -123.146175,
#   '0108 1st & Chestnut',
#   26,
#   'online'),
#  (61,
#   9,
#   7,
#   '51e4d3731aebbf9c3186f310a08de6c8',
#   49.265605,
#   -123.152566,
#   '0109 7th & Arbutus',
#   16,
#   'online'),
#  (62,
#   13,
#   3,
#   '826af7eee4ce28b6fa4b4f0211305792',
#   49.267222,
#   -123.153157,
#   '0110 5th & Arbutus',
#   16,
#   'online'),
#  (63,
#   20,
#   10,
#   '4cb84c9a3743287019ae00ceef9a1cd3',
#   49.262255,
#   -123.126217,
#   '0112 10th & Oak',
#   30,
#   'online'),
#  (64,
#   28,
#   12,
#   '56fef9ba0af67a4ff3e661a8e02c0b08',
#   49.257654,
#   -123.153212,
#   '0113 Arbutus & 16th',
#   40,
#   'online'),
#  (65,
#   11,
#   1,
#   'c81f75a80312c51ceaef1304beac1990',
#   49.25919,
#   -123.148268,
#   '0114 Cypress & 14th',
#   12,
#   'online'),
#  (66,
#   6,
#   6,
#   'afacb2133f2462aba7748cc21b71c788',
#   49.25741,
#   -123.148531,
#   '0115 Cypress & 16th',
#   12,
#   'online'),
#  (67,
#   7,
#   5,
#   'a9f0b06d07f89b75e92c0cf686223aea',
#   49.285953,
#   -123.124066,
#   '0123 Georgia & Thurlow',
#   12,
#   'online'),
#  (68,
#   5,
#   11,
#   '686b314a6c3348efd2297d6b3dfed1a7',
#   49.280881,
#   -123.130672,
#   '0126 Thurlow & Pendrell',
#   16,
#   'online'),
#  (69,
#   10,
#   2,
#   '0d1b5c62f8d22e3650811df55596e25b',
#   49.256845,
#   -123.120071,
#   '0130 Heather & 16th',
#   12,
#   'online'),
#  (70,
#   15,
#   1,
#   '521c2122c791ed038168c3b8ff24061b',
#   49.25849,
#   -123.104799,
#   '0132 14th & Ontario',
#   16,
#   'online'),
#  (71,
#   12,
#   2,
#   '838d5bb59963474ad08a6d5b156943ed',
#   49.258425,
#   -123.100792,
#   '0134 14th & Main',
#   14,
#   'online'),
#  (72,
#   11,
#   7,
#   'b9ab6ce009eda6006ade1d7568d9db9c',
#   49.270905,
#   -123.126006,
#   '0136 David Lam Park - West',
#   18,
#   'online'),
#  (73,
#   0,
#   18,
#   '9ec4163496363b31ab475cb851b57b21',
#   49.273568,
#   -123.129935,
#   '0137 Beach & Seymour',
#   18,
#   'online'),
#  (74,
#   18,
#   0,
#   'fedff7a263c182df94bda7307059cc52',
#   49.277141,
#   -123.122589,
#   '0138 Richards & Helmcken',
#   18,
#   'online'),
#  (75,
#   3,
#   13,
#   'b9baf685b7053de899bf3467f61c2781',
#   49.267859,
#   -123.145782,
#   '0139 Burrard & 4th',
#   16,
#   'online'),
#  (76,
#   14,
#   2,
#   '8d6f0cbf7d44d2908c8ce73ed00dbf66',
#   49.265336,
#   -123.145823,
#   '0140 Burrard & 7th',
#   16,
#   'online'),
#  (77,
#   9,
#   5,
#   '988f8f74c4a12d1a30ddf2f7cd6318f8',
#   49.267628,
#   -123.127698,
#   '0143 South False Creek Seawall',
#   14,
#   'online'),
#  (78,
#   13,
#   3,
#   '2f09a64507cf6257c67ca20af27339eb',
#   49.275938,
#   -123.145939,
#   '0147 Chestnut & McNicoll',
#   16,
#   'online'),
#  (79,
#   4,
#   14,
#   '73f388336d879bedc962cd412eb0296e',
#   49.2756,
#   -123.102661,
#   '0148 Creekside Park North',
#   18,
#   'online'),
#  (80,
#   9,
#   11,
#   'cb6fddfdac7d350d25be475c7ab9e05a',
#   49.284157,
#   -123.099917,
#   '0150 Alexander & Main',
#   20,
#   'online'),
#  (81,
#   12,
#   8,
#   'cadc004f0903ef45e898032143c0832f',
#   49.258924,
#   -123.152591,
#   '0152 Arbutus Greenway & 14th',
#   20,
#   'online'),
#  (82,
#   3,
#   13,
#   '57e928d8c30fab0ebffb3ede850f89d6',
#   49.266774,
#   -123.141135,
#   '0153 Arbutus Greenway & Fir',
#   16,
#   'online'),
#  (83,
#   26,
#   13,
#   '6526a2eb3832f9ba0224d237e901ea5b',
#   49.273355,
#   -123.154493,
#   '0154 Kitsilano Beach Park',
#   39,
#   'online'),
#  (84,
#   7,
#   23,
#   'e44c2235dd603dbee54fe08f7543e85a',
#   49.276144,
#   -123.151272,
#   '0155 Arbutus & McNicoll',
#   30,
#   'online'),
#  (85,
#   15,
#   3,
#   '3596b4831ee2ea7812de753b32306835',
#   49.268339,
#   -123.157443,
#   '0159 Vine & 4th',
#   18,
#   'online'),
#  (86,
#   10,
#   4,
#   'c448b73d92f7f8e1daafb3b9c5fbe6a6',
#   49.284062,
#   -123.095097,
#   '0161 Alexander & Dunlevy',
#   14,
#   'online'),
#  (87,
#   13,
#   1,
#   '5fc29e0ac42c11abb45bf12aaeb925bd',
#   49.261742,
#   -123.13148,
#   '0166 Alder & 11th',
#   14,
#   'online'),
#  (88,
#   12,
#   1,
#   '61901a235d4cfceb7f8f2c3888b98617',
#   49.262206,
#   -123.109091,
#   '0172 10th & Columbia',
#   14,
#   'online'),
#  (89,
#   9,
#   23,
#   '175a074bf65455d1633639511dc129c8',
#   49.27023,
#   -123.10651,
#   '0174 1st & Manitoba',
#   32,
#   'online'),
#  (90,
#   18,
#   2,
#   '35eb539fb9298bb7e4f6759ca0256505',
#   49.262062,
#   -123.104656,
#   '0176 10th & Ontario',
#   20,
#   'online'),
#  (91,
#   1,
#   19,
#   '7b8dfa12900bcb02b47a14e4e5010ba3',
#   49.27033,
#   -123.10275,
#   '0177 Quebec & 1st',
#   20,
#   'online'),
#  (92,
#   13,
#   1,
#   'b30ed0719dd281867a4d39779c78b58a',
#   49.258902,
#   -123.109596,
#   '0180 Columbia & 14th',
#   14,
#   'online'),
#  (93,
#   14,
#   6,
#   'e1a4d91fdae7e18483373f648141e53e',
#   49.282224,
#   -123.132778,
#   '0187 Bute & Davie',
#   20,
#   'online'),
#  (94,
#   13,
#   1,
#   'ace20c241ee38643c9060f290b215b9d',
#   49.265071,
#   -123.123864,
#   '0191 7th & Laurel',
#   14,
#   'online'),
#  (95,
#   15,
#   1,
#   '3aed670ccdcd94b966c0f505f8b028c7',
#   49.265198,
#   -123.131043,
#   '0192 7th &  Alder',
#   16,
#   'online'),
#  (96,
#   2,
#   14,
#   'ae69aeab748d02e5a7d89da28a1a8511',
#   49.273691,
#   -123.102232,
#   '0193 Science World',
#   16,
#   'online'),
#  (97,
#   5,
#   15,
#   '0c9ad3e3703e5869b82619ecdf54f43e',
#   49.2685027,
#   -123.0975014,
#   '0197 1st & Scotia',
#   20,
#   'online'),
#  (98,
#   4,
#   16,
#   '852212d6d52b5f00544fad01d21c7db2',
#   49.278529,
#   -123.100017,
#   '0199 Georgia & Main',
#   20,
#   'online'),
#  (99,
#   8,
#   10,
#   'f3708906ec71348f5a42579fede36a0d',
#   49.288682,
#   -123.11818,
#   '0201 Shaw Tower',
#   18,
#   'online'),
#  (100,
#   11,
#   1,
#   'd145b7498709289702095a4a2fcb2e03',
#   49.258864,
#   -123.14353,
#   '0203 Pine & 14th',
#   12,
#   'online'),
#  (101,
#   2,
#   18,
#   '9449a6a83fbf88452e384350e5ac95b7',
#   49.271741,
#   -123.155421,
#   '0204 York & Yew',
#   20,
#   'online'),
#  (102,
#   16,
#   4,
#   '365da33e9ce06ea53db1173a0f8eae71',
#   49.262822,
#   -123.14338,
#   '0205 Pine & 10th',
#   20,
#   'online'),
#  (103,
#   6,
#   6,
#   '707c1c54e0278fbae5d0ae3c42a25b71',
#   49.263635,
#   -123.099236,
#   '0206 8th & Scotia',
#   12,
#   'online'),
#  (104,
#   19,
#   1,
#   '5105df3dd0daf4c26980f4134f61e5cc',
#   49.28763,
#   -123.127245,
#   '0207 Alberni & Jervis',
#   20,
#   'online'),
#  (105,
#   7,
#   13,
#   '82c794442f54fabf9db6e392ca1fac0f',
#   49.297933,
#   -123.130758,
#   '0209 Stanley Park - Information Booth',
#   20,
#   'online'),
#  (106,
#   8,
#   6,
#   '2ca388bba54706770900ca2a9d7aa5be',
#   49.258819,
#   -123.131317,
#   '0211 14th & Alder',
#   14,
#   'online'),
#  (107,
#   5,
#   9,
#   'e7bf01431a6982f032996ad50a9e5bd7',
#   49.280284,
#   -123.097052,
#   '0213 Pender & Gore',
#   14,
#   'online'),
#  (108,
#   4,
#   14,
#   '1648ead5ea617d2cea115869d9516f5e',
#   49.276294,
#   -123.106534,
#   '0218 Carrall & Seawall',
#   18,
#   'online'),
#  (109,
#   1,
#   13,
#   '91035fe1d70b65c9cb8ec4a007af7c7f',
#   49.277469,
#   -123.081315,
#   '0221 Glen & Union',
#   14,
#   'online'),
#  (110,
#   8,
#   14,
#   'd3aaff4414a8c3fd5480c470f77ff68a',
#   49.277665,
#   -123.073653,
#   '0222 Adanac & McLean',
#   22,
#   'online'),
#  (111,
#   9,
#   7,
#   'b307709b305dd04328fbbf2c6db86419',
#   49.277436,
#   -123.070427,
#   '0223 Commercial & Adanac',
#   16,
#   'online'),
#  (112,
#   4,
#   12,
#   'e9c4bd1fffbb1e5b058b8ea15f7307f6',
#   49.280332,
#   -123.070068,
#   '0224 Pender & Commercial',
#   16,
#   'online'),
#  (113,
#   8,
#   6,
#   'bb0847559ce71c93d8215c0997ea2811',
#   49.279369,
#   -123.091241,
#   '0229 Keefer & Princess',
#   14,
#   'online'),
#  (114,
#   13,
#   7,
#   '1ef5c4ff3f0b09422bb1597fd9d7568b',
#   49.283992,
#   -123.091206,
#   '0230 Alexander & Railway',
#   20,
#   'online'),
#  (115,
#   10,
#   4,
#   'ac3b8198f03754a0afb8b6ed6d220cdd',
#   49.274881,
#   -123.069323,
#   '0231 Napier & Commercial',
#   14,
#   'online'),
#  (116,
#   14,
#   0,
#   '029a505bd4422a1afd127987757f71a6',
#   49.275882,
#   -123.071865,
#   '0232 Britannia Parking Lot',
#   14,
#   'online'),
#  (117,
#   4,
#   10,
#   '0459b7e93703980b853cd65a9dc60596',
#   49.273777,
#   -123.092723,
#   '0233 Thornton & National',
#   14,
#   'online'),
#  (118,
#   12,
#   16,
#   'a21f40838346e300063bdda3c5c04105',
#   49.265005,
#   -123.079481,
#   '0236 Keith & 6th',
#   28,
#   'online'),
#  (119,
#   3,
#   17,
#   '209fb233aff275020a640c8c40a18d90',
#   49.265024,
#   -123.08127,
#   '0237 Glen & 6th',
#   20,
#   'online'),
#  (120,
#   10,
#   4,
#   '6b1622540fe5c85d365754dd8c20bf0c',
#   49.271377,
#   -123.069416,
#   '0239 Grant & Commercial',
#   14,
#   'online'),
#  (121,
#   19,
#   3,
#   'ebc551adb0fc1a684f4080e4954a9ba4',
#   49.268616,
#   -123.069908,
#   '0240 2nd & Commercial',
#   22,
#   'online'),
#  (122,
#   12,
#   2,
#   '6eaa02e5bcf78db5386683d38fa2dabd',
#   49.266969,
#   -123.069936,
#   '0241 4th & Commercial',
#   14,
#   'online'),
#  (123,
#   37,
#   1,
#   '983e58671adcc67af94457d7887dbb15',
#   49.263242,
#   -123.070521,
#   '0242 8th & Commercial',
#   38,
#   'online'),
#  (124,
#   14,
#   12,
#   '797ff1725f8d2b18337de51e240ff60d',
#   49.261403,
#   -123.070102,
#   '0244 10th & Commercial',
#   26,
#   'online'),
#  (125,
#   4,
#   10,
#   '277b4b4881bdb7dac73012672179def8',
#   49.261263,
#   -123.073707,
#   '0245 Woodland & 10th',
#   14,
#   'online'),
#  (126,
#   7,
#   11,
#   'e1ff428dadc7c32141b9d89a7b56728a',
#   49.262242,
#   -123.081459,
#   '0246 Glen & Broadway',
#   18,
#   'online'),
#  (127,
#   11,
#   3,
#   '012d3e06901cc222b1c2cf0a2ace3a29',
#   49.262321,
#   -123.09306,
#   '0248 St George & Broadway',
#   14,
#   'online'),
#  (128,
#   1,
#   11,
#   'a6455af6b689bcbad07ae2c8a3419b50',
#   49.264251,
#   -123.073853,
#   '0249 7th & Woodland',
#   12,
#   'online'),
#  (129,
#   6,
#   8,
#   '475627e149c1a6ba73caac8d8d2fa617',
#   49.266751,
#   -123.073501,
#   '0250 Woodland & 4th',
#   14,
#   'online'),
#  (130,
#   7,
#   5,
#   'f387ec226c432c5c054e3d3616d90501',
#   49.270684,
#   -123.073562,
#   '0252 Woodland & Graveley',
#   12,
#   'online'),
#  (131,
#   5,
#   9,
#   '1675a77b9af656faf527b4e6de53e63b',
#   49.2731,
#   -123.0732,
#   '0253 Charles & Woodland',
#   14,
#   'online'),
#  (132,
#   6,
#   10,
#   '1bca0e944a4faf170db82793414b03ab',
#   49.254667,
#   -123.101389,
#   '0255 18th & Main',
#   16,
#   'online'),
#  (133,
#   14,
#   0,
#   'd0782213f003ce9eb276fbceff44f1f4',
#   49.256694,
#   -123.096579,
#   '0256 Prince Edward & 16th',
#   14,
#   'online'),
#  (134,
#   3,
#   11,
#   '1ef01f2f89621d51afbabaa6296e55be',
#   49.258352,
#   -123.096337,
#   '0257 Prince Edward & 14th',
#   14,
#   'online'),
#  (135,
#   14,
#   2,
#   'c47a1f62ea461ce1c9f3e2478c657df6',
#   49.258817,
#   -123.092797,
#   '0258 13th & St George',
#   16,
#   'online'),
#  (136,
#   9,
#   5,
#   '0cee06d7d10f7d3162cea03d22b7beed',
#   49.26151,
#   -123.089413,
#   '0260 10th & Fraser',
#   14,
#   'online'),
#  (137,
#   16,
#   0,
#   'f62bc2bfe9a0a563d5b6745ce6d962ba',
#   49.263382,
#   -123.088837,
#   '0261 8th & Fraser',
#   16,
#   'online'),
#  (138,
#   7,
#   5,
#   '1c8f7fd6535db12cc45cfc59aa9da058',
#   49.261353,
#   -123.085333,
#   '0265 St Catherines & 10th',
#   12,
#   'online'),
#  (139,
#   18,
#   2,
#   '17a3320a52bcc62161908967f8a06613',
#   49.264466,
#   -123.085183,
#   '0266 St Catherines & 7th',
#   20,
#   'online'),
#  (140,
#   16,
#   0,
#   'aed214941445e0345aa3254805a9e8b8',
#   49.280197,
#   -123.065859,
#   '0272 Pender & Victoria',
#   16,
#   'online'),
#  (141,
#   12,
#   4,
#   'd67640af1b3b3b3ce47169dbc9182470',
#   49.266725,
#   -123.065925,
#   '0273 Victoria & 4th',
#   16,
#   'online'),
#  (142,
#   8,
#   4,
#   'b2c6aaf2b4fa8937bfe3941c038683aa',
#   49.261188,
#   -123.066009,
#   '0274 Victoria & 10th',
#   12,
#   'online'),
#  (143,
#   10,
#   8,
#   '0a43242bee10cd33f539af2c1bf5ecbf',
#   49.256857,
#   -123.065646,
#   '0278 15th & Victoria (Trout Lake)',
#   18,
#   'online'),
#  (144,
#   2,
#   14,
#   '198810b9b0af5d229d1b6fa12c620e06',
#   49.283986,
#   -123.065264,
#   '0280 Triumph & Victoria',
#   16,
#   'online'),
#  (145,
#   2,
#   12,
#   'd02e2eaafda91425eddd24d8acd328ab',
#   49.257985,
#   -123.083366,
#   '0281 Windsor & 14th',
#   14,
#   'online'),
#  (146,
#   11,
#   5,
#   '08c7a90bf297fde8c1f1156db13987d4',
#   49.257939,
#   -123.089531,
#   '0282 14th & Fraser',
#   16,
#   'online'),
#  (147,
#   2,
#   12,
#   '97005696a3dff3366a8410b817388990',
#   49.256496,
#   -123.075426,
#   '0283 15th & Knight',
#   14,
#   'online'),
#  (148,
#   9,
#   7,
#   'c52e51e3288a00993bdf892fdc2c2c2c',
#   49.283236,
#   -123.070443,
#   '0285 Commercial & Pandora',
#   16,
#   'online'),
#  (149,
#   9,
#   7,
#   '7d231a181d21056e4ba80c4d9939fe92',
#   49.267266,
#   -123.090786,
#   '0287 Carolina & Great Northern Way',
#   16,
#   'online'),
#  (150,
#   11,
#   5,
#   'dcf3d5c9f1b3a46f0ef2eb2247931f89',
#   49.265242,
#   -123.095577,
#   '0297 6th & Prince Edward',
#   16,
#   'online'),
#  (151,
#   14,
#   2,
#   '9bee3167f10c884044cea0d36afcd1ef',
#   49.265213,
#   -123.090785,
#   '0298 6th & Carolina',
#   16,
#   'online'),
#  (152,
#   30,
#   8,
#   '45a4c865db23e1cad0209afa5a799de0',
#   49.302577,
#   -123.155616,
#   '0103 Stanley Park - Third Beach Parking Lot',
#   38,
#   'online'),
#  (153,
#   2,
#   14,
#   'fe0c57d04d6e682d284d501446095fc9',
#   49.277595,
#   -123.09583,
#   '0212 Union & Dunlevy',
#   16,
#   'online'),
#  (154,
#   4,
#   12,
#   'b10d422b045805f1c350c47c983381e8',
#   49.279235,
#   -123.087528,
#   '0228 Keefer & Hawks',
#   16,
#   'online'),
#  (155,
#   1,
#   15,
#   '4e8fdc99e77ba1b70d90e124a704d0c1',
#   49.277333,
#   -123.087359,
#   '0219 Hawks & Union',
#   16,
#   'online'),
#  (156,
#   6,
#   16,
#   'b562f08327af465e4531e20226789489',
#   49.273103,
#   -123.069892,
#   '0235 Charles & Commercial',
#   22,
#   'online'),
#  (157,
#   14,
#   6,
#   '4ac99b928a91d8ccb785c9d0b805adb6',
#   49.261973,
#   -123.09725,
#   '0186 10th & Kingsway',
#   20,
#   'online'),
#  (158,
#   2,
#   16,
#   '99c81f71db35911c79a86a1c5edc5604',
#   49.275295,
#   -123.132585,
#   '0045 Beach & Hornby',
#   18,
#   'online'),
#  (159,
#   21,
#   7,
#   'e12234b6f1299d178f34bffaca92f043',
#   49.285871,
#   -123.12105,
#   '0002 Burrard Station (Melville & Dunsmuir)',
#   28,
#   'online'),
#  (160,
#   6,
#   8,
#   '5a34495280727a5b50b9aa41e14e9a16',
#   49.284893,
#   -123.128685,
#   '0300 Bute & Barclay',
#   14,
#   'online'),
#  (161,
#   12,
#   10,
#   '9130f9aa3bb037a04c17e6f2630327e5',
#   49.263962,
#   -123.112621,
#   '0170 8th & Yukon',
#   22,
#   'online'),
#  (162,
#   0,
#   12,
#   '9a48ca226f82f52d02707b054ebc7e9e',
#   49.277615,
#   -123.091654,
#   '0215 Princess & Union',
#   12,
#   'online'),
#  (163,
#   18,
#   6,
#   'b3bb9f58d3530d33a1a09b6be9e973e0',
#   49.282214,
#   -123.114101,
#   '0012 Dunsmuir & Richards',
#   24,
#   'online'),
#  (164,
#   12,
#   8,
#   'c2f4e05c01ea0d27934ac7dbc50cbd0c',
#   49.266456,
#   -123.100324,
#   '0198 5th & Main',
#   20,
#   'online'),
#  (165,
#   7,
#   13,
#   '9a5478470b56379c31cf4e671584d5cc',
#   49.268216,
#   -123.103168,
#   '0119 3rd & Quebec',
#   20,
#   'online'),
#  (166,
#   12,
#   12,
#   '257715b845828e027ff35dd0f11c971e',
#   49.284554,
#   -123.111031,
#   '0124 Richards & Cordova',
#   24,
#   'online'),
#  (167,
#   20,
#   2,
#   '910027847876403b57f1013c16504688',
#   49.280216,
#   -123.117639,
#   '0129 Richards & Robson',
#   22,
#   'online'),
#  (168,
#   5,
#   21,
#   '06487275cd19694152824c7c3088e8ff',
#   49.266314,
#   -123.116011,
#   '0006 Olympic Village Station',
#   26,
#   'online'),
#  (169,
#   9,
#   5,
#   'b428c0e64d9b9fdb3bf8e85c95ffdf6b',
#   49.280852,
#   -123.084746,
#   '0227 Campbell & Hastings',
#   14,
#   'online'),
#  (170,
#   8,
#   10,
#   'd085c6749a32517e1fb0d070e4128402',
#   49.285512,
#   -123.1384,
#   '0040 Cardero & Davie',
#   18,
#   'online'),
#  (171,
#   15,
#   20,
#   'a6aec7b8c25da4c02829cd7839b8933d',
#   49.27821,
#   -123.136972,
#   '0083 Aquatic Centre',
#   35,
#   'online'),
#  (172,
#   17,
#   5,
#   'c924f6a41b130fad49cfae47271314bc',
#   49.281301,
#   -123.139108,
#   '0084 Beach & Broughton',
#   22,
#   'online'),
#  (173,
#   8,
#   14,
#   '8e93d0da1ee6caadf21ed9575b5fa9da',
#   49.283298,
#   -123.142288,
#   '0142 Beach & Cardero',
#   22,
#   'online'),
#  (174,
#   8,
#   10,
#   '9413725a5d3bb5ce2ad0682b07a3ffab',
#   49.280787,
#   -123.115271,
#   '0305 Georgia & Homer',
#   18,
#   'online'),
#  (175,
#   4,
#   14,
#   '7ed043a19e6a4ece742fe747b663bdbf',
#   49.266476,
#   -123.109389,
#   '0165 Columbia & 5th',
#   18,
#   'online'),
#  (176,
#   2,
#   18,
#   'ce5dccf5a0f190bb4567a2fd93e7971e',
#   49.290587,
#   -123.13625,
#   '0122 Haro & Denman',
#   20,
#   'online'),
#  (177,
#   19,
#   3,
#   '844aa75af0d3235a86ff827c81395afd',
#   49.312568,
#   -123.144177,
#   '0100 Stanley Park - Prospect Point',
#   22,
#   'online'),
#  (178,
#   15,
#   3,
#   '1d442ad1a71774c82688a45954e47bfd',
#   49.262835,
#   -123.152626,
#   '0075 Arbutus & 10th',
#   18,
#   'online'),
#  (179,
#   10,
#   4,
#   '2781435bde344e1b64f1bebac6bc9008',
#   49.256825,
#   -123.105234,
#   '0133 Ontario & 16th',
#   14,
#   'online'),
#  (180,
#   3,
#   11,
#   'e9b37f2d9b7b2e2e3ade73f13acb69b2',
#   49.275683,
#   -123.124388,
#   '0082 Richards & Davie',
#   14,
#   'online'),
#  (181,
#   12,
#   6,
#   'fffd87607aaae16fbb1f71615cbe7d17',
#   49.263518,
#   -123.09568,
#   '0262 8th & Prince Edward',
#   18,
#   'online'),
#  (182,
#   17,
#   3,
#   'da8b6e94f90ad41a3f8de10596992372',
#   49.28691,
#   -123.128818,
#   '0310 Jervis & Robson',
#   20,
#   'online'),
#  (183,
#   17,
#   3,
#   '32f70f7ae14ba87523c6286a6c4d5c37',
#   49.282503,
#   -123.124697,
#   '0217 Smithe & Burrard',
#   20,
#   'online'),
#  (184,
#   11,
#   11,
#   'df5ab349a7a85d4b10da4cc3ec65c607',
#   49.283749,
#   -123.136133,
#   '0087 Broughton & Davie',
#   22,
#   'online'),
#  (185,
#   12,
#   2,
#   'e0318460138ffbf4692005d5b5a9f900',
#   49.262944,
#   -123.148109,
#   '0068 Cypress & 10th',
#   14,
#   'online'),
#  (186,
#   4,
#   16,
#   'db51c556fe50ec1deefbc9697c70cb51',
#   49.27029,
#   -123.135025,
#   '0189 Granville Island',
#   20,
#   'online'),
#  (187,
#   6,
#   10,
#   '58a026f0c506caec20697a4f90538450',
#   49.280427,
#   -123.074082,
#   '0225 McLean & Pender',
#   16,
#   'online'),
#  (188,
#   18,
#   0,
#   '0e0aef6fabaa808b3a3cef24657257a4',
#   49.279259,
#   -123.119145,
#   '0058 Richards & Smithe',
#   18,
#   'online'),
#  (189,
#   8,
#   18,
#   '90c746df94ce1a12f1f617acfe4a8ce3',
#   49.285836,
#   -123.127265,
#   '0036 Bute & Robson',
#   26,
#   'online'),
#  (190,
#   17,
#   3,
#   '80b5c12ef21fd47275d37b2c9935249c',
#   49.272969,
#   -123.164325,
#   '0460 Trafalgar & Cornwall',
#   20,
#   'online'),
#  (191,
#   20,
#   4,
#   '899f59a9994302e8e1e4be01117ef707',
#   49.27247,
#   -123.185643,
#   '0410 Alma & Point Grey',
#   24,
#   'online'),
#  (192,
#   4,
#   10,
#   '8d2d5bb3b9142f781f2a7f441e6bad7a',
#   49.271471,
#   -123.17731,
#   '0440 Point Grey & Blenheim',
#   14,
#   'online'),
#  (193,
#   15,
#   9,
#   '5de0fe55497681d4cc9dd25509cf51ab',
#   49.290112,
#   -123.127062,
#   '0035 Hastings & Broughton',
#   24,
#   'online'),
#  (194,
#   1,
#   17,
#   '2681455ba2d97283998a806b14d3e95c',
#   49.263523,
#   -123.155267,
#   '0484 Yew & Broadway',
#   18,
#   'online'),
#  (195,
#   10,
#   12,
#   '064a7b39b1dbc4bfc4cf8f454e360c57',
#   49.264928,
#   -123.168068,
#   '0452 8th & Macdonald',
#   22,
#   'online'),
#  (196,
#   14,
#   4,
#   '9c1397c06e07bf74fc049f1a0872eea0',
#   49.264483,
#   -123.173926,
#   '0444 Balaclava & Broadway',
#   18,
#   'online'),
#  (197,
#   19,
#   7,
#   '9763838317308a4766b83696986a157b',
#   49.264579,
#   -123.18373,
#   '0415 Dunbar & Broadway',
#   26,
#   'offline'),
#  (198,
#   7,
#   9,
#   'c64ee19c62a363019ddbaedf71df2882',
#   49.263746,
#   -123.069892,
#   '0254 Grandview & Commercial',
#   16,
#   'online'),
#  (199,
#   12,
#   2,
#   '421516af381a11f54d07fc79be68d3d3',
#   49.258761,
#   -123.127071,
#   '0202 14th & Oak',
#   14,
#   'online'),
#  (200,
#   9,
#   9,
#   '38f045e3f43f86eae42ca4c60257ade0',
#   49.268974,
#   -123.190701,
#   '0401 Wallace & 4th',
#   18,
#   'online'),
#  (201,
#   6,
#   14,
#   '5ba6e9725b1b0ee8cd25df976e47726b',
#   49.273011,
#   -123.159663,
#   '0470 Balsam & Cornwall',
#   20,
#   'online'),
#  (202,
#   8,
#   8,
#   'f90ed7ad754ec04b7852941a480a4c77',
#   49.266924,
#   -123.173849,
#   '0443 Balaclava & 6th',
#   16,
#   'online'),
#  (203,
#   5,
#   11,
#   'abfaf72456a4828a22f5bf60d3a80777',
#   49.264326,
#   -123.164725,
#   '0464 Trafalgar & Broadway',
#   16,
#   'online'),
#  (204,
#   6,
#   10,
#   '2ff7eb4230654603592ab1b0780ec5e1',
#   49.266636,
#   -123.183661,
#   '0414 Dunbar & 6th',
#   16,
#   'online'),
#  (205,
#   14,
#   10,
#   'ea9485fcdce0611243474d000e4ad248',
#   49.254818,
#   -123.114785,
#   '0531 18th & Cambie',
#   24,
#   'online'),
#  (206,
#   21,
#   2,
#   '671ce9e4a92063620f772d2c57f0f3ab',
#   49.268837,
#   -123.177633,
#   '0431 Blenheim & 4th',
#   23,
#   'online'),
#  (207,
#   16,
#   0,
#   '41a55a7e2908fbbd65175b794d26bc8d',
#   49.255034,
#   -123.120226,
#   '0511 18th & Heather',
#   16,
#   'online'),
#  (208,
#   3,
#   13,
#   'a59924f0ff3fb481a7bd8a5e9c36858f',
#   49.271044,
#   -123.170661,
#   '0450 Point Grey & Bayswater',
#   16,
#   'online'),
#  (209,
#   7,
#   9,
#   '89a0b49a66e54a7639ad960962148a3e',
#   49.252691,
#   -123.101289,
#   '0561 20th & Main',
#   16,
#   'online'),
#  (210,
#   12,
#   6,
#   '44fc3d58831a9f2b919c7a3a1838b74a',
#   49.272172,
#   -123.097978,
#   '0354 Station & Terminal',
#   18,
#   'online'),
#  (211,
#   18,
#   16,
#   'd40db8c27c5bd409d57cfa846f73c378',
#   49.271082,
#   -123.191458,
#   '0400 Jericho Beach',
#   34,
#   'online'),
#  (212,
#   24,
#   0,
#   '4990fe5772f3b73eebeec125b41e478e',
#   49.27808,
#   -123.130557,
#   '0089 Burrard & Drake',
#   24,
#   'online'),
#  (213,
#   12,
#   11,
#   'bf96df77771ef0ed710d8e0e67917f45',
#   49.269969,
#   -123.109623,
#   '0173 Columbia & 1st',
#   24,
#   'online'),
#  (214,
#   16,
#   14,
#   'e75e83499d3fa2e174dc2a8ffd238119',
#   49.287528,
#   -123.142139,
#   '0028 Davie & Beach',
#   30,
#   'online'),
#  (215,
#   12,
#   12,
#   '0438114d2e6b96118de69bc9775bb21e',
#   49.28803,
#   -123.142135,
#   '0031 Morton & Denman',
#   24,
#   'online'),
#  (216,
#   8,
#   6,
#   '07b13214cb69f2ec007d888450f3d6bc',
#   49.259579,
#   -123.114769,
#   '0311 13th & Cambie',
#   14,
#   'online'),
#  (217,
#   5,
#   12,
#   'f5e8fa1fc4252bda2f93dd27ed2d603f',
#   49.28907059898648,
#   -123.13840736946824,
#   '0313 Nelson & Denman',
#   18,
#   'online'),
#  (218,
#   0,
#   14,
#   'c2a9c5d0e4578b928554c86f3d2c1162',
#   49.287782,
#   -123.12395,
#   '0190 Melville & Bute',
#   14,
#   'online'),
#  (219,
#   16,
#   3,
#   '5f45325fdd6334a4c0d3b62853b19fa6',
#   49.28512,
#   -123.11242,
#   '0308 Seymour & Cordova',
#   19,
#   'online'),
#  (220,
#   8,
#   10,
#   '085a0e120a08a80a58c0ae0ff9da565a',
#   49.247854,
#   -123.153422,
#   '0480 Arbutus & Nanton',
#   18,
#   'online'),
#  (221,
#   14,
#   3,
#   '8d5f47f01d7ad668419dfe9b7fe69c9a',
#   49.265939,
#   -123.1129,
#   '0171 Yukon & 6th',
#   18,
#   'online'),
#  (222,
#   12,
#   2,
#   'bede4b24dae115d4cd43d2e6cc9812cb',
#   49.261122,
#   -123.097571,
#   '0179 11th & Kingsway',
#   16,
#   'online'),
#  (223,
#   10,
#   8,
#   '680b1ddfd50c4397b365c9c00f09b0d1',
#   49.267725,
#   -123.11311,
#   '0144 Wylie & 2nd',
#   18,
#   'online'),
#  (224,
#   18,
#   2,
#   'b26f83e904f3a778466ebcd763b7316a',
#   49.245135,
#   -123.116098,
#   '0526 29th & Cambie',
#   20,
#   'online'),
#  (225,
#   0,
#   16,
#   '6620c54bd6b3a79800b2b67e999b24d0',
#   49.274232,
#   -123.129998,
#   '0314 Rolston & Granville',
#   16,
#   'online'),
#  (226,
#   16,
#   4,
#   '7f091b50fbbd892bf9fb869a64c47120',
#   49.238105,
#   -123.154966,
#   '0482 East Blvd & 37th',
#   20,
#   'online'),
#  (227,
#   10,
#   10,
#   '57d39a680c9407cda0fb4de6d9c55138',
#   49.246243,
#   -123.124373,
#   '0505 28th & Willow',
#   20,
#   'online'),
#  (228,
#   7,
#   5,
#   '97388f4e4ea102a30345524bda465f4e',
#   49.249722,
#   -123.104991,
#   '0554 Ontario & 23rd',
#   12,
#   'online'),
#  (229,
#   5,
#   17,
#   '066ecc3584913fa035ec1417323beb80',
#   49.243375,
#   -123.104978,
#   '0557 30th & Ontario',
#   22,
#   'online'),
#  (230,
#   16,
#   4,
#   'b530d04d393d71cffb8b8b07f4a82380',
#   49.282087,
#   -123.056909,
#   '0642 Franklin & Nanaimo',
#   20,
#   'online'),
#  (231,
#   16,
#   0,
#   '06bdc4d55f34b2a491305534fd5defda',
#   49.283968,
#   -123.061615,
#   '0631 Lakewood & Triumph',
#   16,
#   'online'),
#  (232,
#   10,
#   8,
#   '8e44a17d2fa446ca220b90c7063b42ca',
#   49.287464,
#   -123.060771,
#   '0611 Wall & Eton',
#   18,
#   'online'),
#  (233,
#   10,
#   8,
#   '7c17f51469f1a7145455f65ef6afbd87',
#   49.285575,
#   -123.061575,
#   '0621 Lakewood & Oxford',
#   18,
#   'online'),
#  (234,
#   15,
#   1,
#   'e1432b72df561a1df34290679ec9c773',
#   49.251358,
#   -123.115637,
#   '0532 22nd & Cambie',
#   16,
#   'online'),
#  (235,
#   18,
#   0,
#   '549f00f6039e8bb702a00dcca08a8ed0',
#   49.249184,
#   -123.116141,
#   '0524 King Edward & Cambie',
#   18,
#   'online'),
#  (236,
#   20,
#   2,
#   'd8c4fe5e09b6f010fbaa85cc7302d66b',
#   49.245535,
#   -123.120496,
#   '0516 Heather & 29th',
#   22,
#   'online'),
#  (237,
#   4,
#   22,
#   '0c42f45e4a14957ad4a6d521d0ba8bc3',
#   49.289255,
#   -123.132677,
#   '0041 Cardero & Robson',
#   26,
#   'online'),
#  (238,
#   13,
#   5,
#   '62a202eb98c0a4b09ba6746f5ee94ab3',
#   49.252656,
#   -123.067965,
#   '0352 Commercial & 20th',
#   18,
#   'online'),
#  (239,
#   13,
#   11,
#   'a6c6df138cbc97b9f81e7ffbbebdde6f',
#   49.277527,
#   -123.129464,
#   '0196 Hornby & Drake',
#   24,
#   'online'),
#  (240,
#   10,
#   8,
#   '04f64fde5ba1ebde8ad78c74914adb34',
#   49.259469,
#   -123.145718,
#   '210 Burrard & 14th',
#   18,
#   'online')]

# %% [markdown]
# ### Look at the data before and after the join to validate your data.

# %% [markdown]
# ## FSQ and Citybike Stations

# %%
create_bike_fsq_data_table = """
CREATE TABLE IF NOT EXISTS bike_stations_fsq (
    Station_ID VARCHAR NOT NULL,
    name TEXT NOT NULL,
    total_slots INTEGER,
    empty_slots INTEGER,
    free_bikes INTEGER,
    longitude FLOAT,
    latitude FLOAT,
    status TEXT
);
# """

# %%
# after creating SQL table header
execute_query(connection, create_bike_fsq_data_table)

# %% [markdown]
# ## Yelp and Citybike Stations
